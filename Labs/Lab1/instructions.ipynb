# %% [markdown]
# ## Lab: Using GitHub Copilot for Test Plan Generation
#
# <span style="font-size:110%">
# Welcome to the Github Copilot Lab! In this hands-on session, you'll learn how to leverage GitHub Copilot, an AI-powered coding assistant, to supercharge your testing workflow. We'll focus on using the Copilot Chat feature (Ask mode) to generate a comprehensive test plan for a software feature. By the end of this lab, you'll have practical experience with Copilot's capabilities and understand how to use it effectively in your testing process.
# </span>
# ---
#
# ## Meet Robo1: Your AI-Powered Testing Sidekick
# <table>
#     <tr>
#         <td style="width:50%; text-align:center;">
#             <img src="../images/robo1.png" alt="Robo1" style="max-width:100%;">
#         </td>
#         <td style="width:50%; ">
#            I help manual testers turn requirements into test cases in seconds! I love finding edge cases and making bugs nervous. With Copilot, testing is faster, smarter, and a lot more fun!
#         </td>
#     </tr>
# </table>
# ---
#
# ### 1. Introduction to GitHub Copilot
# - GitHub Copilot is an AI-powered coding assistant that helps you write code, generate documentation, and automate tasks directly in your editor.
# - It can suggest code, explain code, and answer questions using natural language prompts.
#
# ### 2. Copilot Usage
# - **Inline Suggestions**: Copilot suggests code as you type.
# - **Copilot Chat**: Use the chat sidebar or command palette to ask questions, get explanations, or generate code/tests.
#
# > This lab is focused only on using GitHub Copilot features. Prompt engineering techniques are not covered here.

# %% [markdown]
# ---
#
# ## Part 1 — Setup: VS Code + GitHub Copilot
#
# ### 1.1 Install the GitHub Copilot Extension
#
# <span style="color:orange">Step 1:</span> Open **VS Code**
#
# <span style="color:orange">Step 2:</span> Press <kbd>Ctrl</kbd>+<kbd>Shift</kbd>+<kbd>X</kbd> to open the **Extensions** panel
#
# <span style="color:orange">Step 3:</span> Search for **`GitHub Copilot`**
#
# <span style="color:orange">Step 4:</span> Click **Install** on the extension published by **GitHub**
#
# > ✅ Install both: **GitHub Copilot** and **GitHub Copilot Chat** (they often install together)
#
# ---
#
# ## 1.2 Sign In to GitHub
#
# <span style="color:orange">Step 5:</span> After installation, VS Code will prompt you to **Sign in to GitHub**
# - Click **Sign in to GitHub** in the notification
# - Your browser will open — complete the GitHub login
# - Return to VS Code — you are now authenticated
#
# > 💡 If no prompt appears: open the Command Palette (<kbd>Ctrl</kbd>+<kbd>Shift</kbd>+<kbd>P</kbd>) → type **`GitHub Copilot: Sign In`**
#
# ---
#
# ## 1.3 Verify Copilot Is Active
#
# <span style="color:orange">Step 6:</span> Look at the **bottom-right of the VS Code status bar**
#
# | What You See | Meaning |
# |---|---|
# | 🤖 *(Copilot icon, no warning)* | ✅ Copilot is active and ready |
# | 🤖 with ⚠️ | ⚠️ Signed out — click to sign in |
# | 🤖 with ✗ | ❌ No subscription or extension disabled |
#
# <span style="color:orange">Step 7:</span> Click the Copilot icon in the status bar to see options — you should see **"Copilot is ready"**

# %% [markdown]
# ---
#
# ## 1.4 Quick Tour of the Copilot Chat Interface
#
# ### 🟢 Surface 3: Copilot Chat Panel
#
#
#
# **Where:** Left sidebar (speech-bubble icon) or press <kbd>Ctrl</kbd>+<kbd>Alt</kbd>+<kbd>I</kbd>
#
# **Best for:** Multi-step conversations, code review, generating test scenarios from requirements
#
# The Chat panel has three **modes** (shown as tabs or a dropdown in the input box):
#
# | Mode | What it does | Best for testers |
# |------|-------------|------------------|
# | **Ask** | Answers questions, explains code | Understanding code before testing it |
# | **Edit** | Makes changes to your open files | Updating test files directly |
# | **Agent** | Runs multi-step tasks across files | Complex test generation (advanced) |
#
# > 💡 **For this lab, we'll primarily use Ask mode and Inline Chat.** Edit and Agent modes are covered in later labs.

# %% [markdown]
# ### 2.1 Copilot Chat — Ask Mode
#
# Use **Ask mode** when you want Copilot to answer questions without touching your files.
#
# ### ✏️ Try It Now
#
# <span style="color:orange">Step 4:</span> Open the **Copilot Chat panel** (speech-bubble icon in the sidebar)
# <span style="color:orange">Step 5:</span> Make sure the mode selector shows **Ask**
# <span style="color:orange">Step 6:</span> Paste this prompt and press Enter:
#
# ```
# Explain what a good test scenario for an "Add to Cart" feature should cover.Give examples of positive cases, negative cases, and edge cases.
# ```
#
# > 💡 Copilot will respond with a structured explanation. This is useful for **learning** and for **reviewing** whether your test scenarios are complete.
#
# ---
#
# ### 2.2 Using `#file` to Give Copilot Context
#
# Copilot is smarter when you point it at the right files.
#
# ### ✏️ Try It Now
#
# <span style="color:orange">Step 11:</span> In the Copilot Chat panel, type:
#
# ```
# #file:ecommerce-Jira.md
#
# Based on the story EC-201 in this file, what test cases should I write?
# ```
#
# > 💡 The `#file:` prefix tells Copilot exactly which file to read. This is called **context attachment**. Without it, Copilot guesses from your open tabs — with it, you get much more accurate results.
#
# Other useful context prefixes:
#
# | Prefix | What it attaches |
# |--------|------------------|
# | `#file:filename.md` | A specific file |
# | `#selection` | Your currently selected text |
# | `#codebase` | Searches the whole project (Agent mode) |

# %% [markdown]
# ---
#
# ### Lab Summary - What did you learn?
#
# - Installed and verified GitHub Copilot
# - Used Chat Panel in Ask Mode
# - Used `#file:` context attachment
# - Generated test scenarios from EC-302 with Copilot
