# %% [markdown]
# ### Lab 2: Inline Editing in Copilot
#
# <span>
# This lab will also introduce you to inline editing with GitHub Copilot. Inline editing allows you to select code directly in your editor and use Copilot to explain, modify, or improve it—right where you work. You'll see how Copilot can help you understand code, suggest fixes, and generate tests, all without leaving your coding environment.
# </span>
# ---

# %% [markdown]
# ### Meet Robo2: InLine Editor Extraordinaire!
# <table>
#     <tr>
#         <td style="width:50%; text-align:center;">
#             <img src="../../images/robo1.png" alt="Robo1" style="max-width:100%;">
#         </td>
#         <td style="width:50%; ">
#             <ul>
#                 <li>Did someone say “bug”? I’m already on it—faster than a runaway thread!</li>
#                 <li>My favorite snack? Null pointers dipped in stack traces. Crunchy!</li>
#                 <li>Debugging is my cardio—watch me break a sweat chasing infinite loops!</li>
#                 <li>I can spot a missing semicolon from a mile away (and I’ll throw a dance party when I find it)!</li>
#             </ul>
#         </td>
#     </tr>
# </table>
# ---

# %% [markdown]
# ## Exercise 1: Fix the Bug with Copilot
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Open ecommerce.spec.js from Lab2</span>

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Use Copilot Explain</span>
#
# Use Github Copilot explain to learn what this code is doing. Copilot might tell you that your code is not right and whats the issue</br>
#
# <span style="color:green;">Select the code  → right click  → Explain</span>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 3:</span> <span style="color:#1976d2;">Fix the issue</span>
#
# Fix the buggy test code.</br></br>
# <span style="color:green;">
# Select the buggy code -> right click -> Generate code -> Fix
# </span>
# <span style="color:green;">
# <pre style="background-color:#23272f; color:#e0e0e0; padding:8px; border-radius:6px;">
# Once you click on fix, copilot will generate the code for you,
# also explaining you the potential issue in the code and how
# the fix is solving that issue.
# </pre>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
#
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 4:</span> <span style="color:#1976d2;">Accept the changes</span>
#
# Review the changes made and if you are satified with the changes, then accept the changes.</br></br>
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
#
# </div>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Exercise 2: Review the Code with Copilot

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Open ecommerce.spec.js from Lab2</span>

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Use Copilot Explain</span>
#
# Use Github Copilot Review  to review your code. Copilot might tell you what are the potential issues and suggest you changes</br>
#
# <span style="color:green;">Select the code  → right click  → Generate code -> Review</span>
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 4:</span> <span style="color:#1976d2;">Accept/Discard the changes</span>
#
# Review the comments provided. You can either accept or discard the changes and move to next comment</br></br>
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Exercise 3: Adding New Test with Copilot

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Open ecommerce.spec.js from Lab2</span>

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Use Inline Editor</span>
#
# - Place your cursor after TC-001.
# - Open the inline editor using Ctrl+I.
# - In the prompt, type # and choose the file from the picker (or type the filename directly, like #ecommerceJira.md).
# - Write your instruction and press Enter.
# - Select the model you want to use for code generation (e.g., GPT-4).
#
# Prompt
# - <code>Using summary and assumptions provided in Jira story Ec-201 from #ecommerceJira.md as reference, add a new test case TC-002: Add item to cart and verify cart count</code>
#
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <table>
#     <tr>
#         <td style="width:50%; text-align:center;">
#             <img src="../../images/robo2.png" alt="Robo1" style="max-width:100%;">
#         </td>
#         <td style="width:50%; vertical-align:middle;">
#             <span style="font-size:120%; color:#1976d2; font-weight:bold;">
#                 🎉 Congratulations!</span><br>You did it!<br>
#                 <span style="color:#43a047;">Happy Coding with your new skills!</span><br>
#             </span>
#         </td>
#     </tr>
# </table>
