# %% [markdown]
# # Working with MCP Servers

# %% [markdown]
# ### Introduction
#
# In this Lab, we will add the Playwright MCP Server into our GitHub Copilot environment.

# %% [markdown]
# <div style="background: #111; border-radius: 12px; border: 2px solid #333; padding: 20px; display: flex; align-items: center; gap: 24px;">
#     <img src="../images/robo1.png" alt="Robo1" style="width: 120px; height: auto; border-radius: 8px;">
#     <div style="color: #fff;">
#         <strong>Robo1 says:</strong><br>
#         Ready to explore the world of MCP Server and see the magic? With Playwright MCP Server, you can automate browser interactions and test your web applications like a pro! Let's dive in and unleash the power of MCP Server together!
#     </div>
# </div>

# %% [markdown]
# <div style="background: #222; border-radius: 12px; border: 2px solid #444; padding: 20px; color: #fff; margin-top: 16px;">
#   <strong>Explore MCP Servers!</strong><br>
#   Visit <a href="https://github.com/modelcontextprotocol/servers?tab=readme-ov-file" target="_blank" style="color: #4fc3f7; text-decoration: underline;">this link</a> and explore all available MCP Server projects. Discover the variety of tools and integrations you can use in your own AI workflows!
# </div>

# %% [markdown]
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 1:</span> <span style="color:#1976d2;">Browse MCP Servers</span>
#  <div style="background-color:black; padding:10px; border-radius:8px;">
#
# Lets install MCP Servers in our VS Studio Code, click on extensions icon in left sidebar and in bottom, you will find MCP Servers, click on browse button to search for available MCP Servers.
#
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 2:</span> <span style="color:#1976d2;">Install Playwright MCP</span>
#  <div style="background-color:black; padding:10px; border-radius:8px;">
#
# Write playwright in search bar and click on install button to install Playwright MCP Server in your VS Studio Code.
#
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 3:</span> <span style="color:#1976d2;">Open New Chat Session</span>
#
# Click on + button on right top corner of copilot chat window to open new chat session
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 4:</span> <span style="color:#1976d2;">Select Agent Mode</span>
#
# To use MCP Server, you need to select Agent Mode in copilot chat. Click on dropdown which is by default in Direct mode and select Agent Mode to switch to agent mode.
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the screenshot below</span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; Step 4:</span> <span style="color:#1976d2;">Test Playwright MCP Server</span>
#
# Run below prompt in copilot chat to test Playwright MCP Server
#
# <span style="font-size:180%; color:#1976d2;">&#8595;</span>
# <span style="color:orange;">Refer the below prompt </span> </br>
# Use playwright mcp server, Go to wikipedia page [homepage](https://en.wikipedia.org/wiki/Donald_Trump), click on View history top bar and take a screenshot of the page and save it as donald_trump_revision_history.png in your Lab3 folder.
# </div>

# %% [markdown]
# ### Challenge:
#
# <div style="background-color:black; padding:10px; border-radius:8px;">
# <span style="font-size:120%; font-weight:bold; color:#1976d2;">&#x1F4DD; </span> <span style="color:#1976d2;"> Now its your turn</span>
#
# Trying adding Atlassian MCP Server in your VS Code and test it by asking copilot to read a jira ticket for you.

# %% [markdown]
# <div style="background: #111; border-radius: 12px; border: 2px solid #333; padding: 20px; display: flex; align-items: center; gap: 24px;">
#     <img src="../images/robo1.png" alt="Robo1" style="width: 120px; height: auto; border-radius: 8px;">
#     <div style="color: #fff;">
#         <strong>Robo1 says:</strong><br>
#         <span style="font-size:120%; color:#4fc3f7;">🎉 Congratulations!</span><br>
#         You did it! Playwright MCP Server is now part of your Copilot arsenal.<br>
#     </div>
# </div>
